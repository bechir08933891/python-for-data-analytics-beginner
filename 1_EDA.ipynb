# %% [markdown]
# # Exploratory data analysis & intro
# **Goal**
# 1. investigate top-paying roles and skills in the data science industry
# 2. Use Python to explore a real live dataset on job posting
# 3. for job seekers: use these insights to help find the best job opportunities
# **Final deliverables:**
# * create jupyter notbooks (showcasing core skills in python)
# * create a summary page via readme.md capturing your findings
# * share this project via github & linkedin

# %%
# !pip install datasets

# %%
# import ast , pandas, seaborn, datasets , matplotlib
import ast
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datasets import load_dataset

# %%
# load the data 
data = load_dataset("lukebarousse/data_jobs")

# %%
# convert data to pandas dataframe
df = data['train'].to_pandas()

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
# data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
# filter data for US country and job title data analyst
df_DA_US = df[(df['job_country'] == 'United States') & (df['job_title_short'] == 'Data Analyst')]

# %%
# print out the df_DA_US
df_DA_US.head()
# Out:
#    job_title_short                                     job_title  \
# 36    Data Analyst                                  Data Analyst
# 68    Data Analyst                     Sr. Research Data Analyst
# 73    Data Analyst   Entry level / Systems Data Analyst (Remote)
# 79    Data Analyst                    Data Analyst/Report Writer
# 93    Data Analyst  IT Finance / TBM Data Analyst - Remote | WFH
#
#       job_location               job_via job_schedule_type  \
# 36  Des Moines, IA       via Trabajo.org         Full-time
# 68   Baltimore, MD      via ZipRecruiter         Full-time
# 73        Anywhere          via LinkedIn        Contractor
# 79      Austin, TX  via Jobs Trabajo.org         Full-time
# 93        Anywhere          via LinkedIn         Full-time
#
#     job_work_from_home          search_location     job_posted_date  \
# 36               False  Illinois, United States 2023-11-06 13:01:22
# 68               False  New York, United States 2023-03-24 13:01:00
# ...

# %%
# count the job location
df_plot = df_DA_US['job_location'].value_counts().head(10).to_frame()

# %%
# plot df_plot
sns.barplot(x='count', y='job_location', data=df_plot, hue='count', palette='viridis')
plt.title('Top 10 Job Locations for Data Analyst in the US')
sns.despine()
plt.xlabel('Count of jobs')
plt.ylabel('')
plt.show()

# %%
# 3 pie chart together
dict_column = {
    'job_work_from_home': 'work from home offred',
    'job_no_degree_mention': 'degree requirement',
    'job_health_insurance': 'health insurance offred'
}
fig, ax = plt.subplots(1, 3)
fig.set_size_inches(18, 6)

for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df_DA_US[column].value_counts(), labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
    ax[i].set_title(title)
plt.show()

# %%
# count comapny names
df_plot = df_DA_US['company_name'].value_counts().head(10).to_frame()
sns.barplot(x='count', y='company_name', data=df_plot, hue='count', palette='viridis')
plt.title('Top 10 companies name for Data Analyst in the US')
sns.despine()
plt.xlabel('Count of companies')
plt.ylabel('')
plt.show()
