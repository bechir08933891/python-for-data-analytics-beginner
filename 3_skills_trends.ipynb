# %% [markdown]
# # How are in demand skills trendiing for data analysts?
#
# **Methodology**
#
# 1. Aggregate skill counts monthly
# 2. Re-analyze based on percentage of total jobs
# 3. Plot the monthly skill demand

# %%
# import ast , pandas, seaborn, datasets , matplotlib
import ast
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datasets import load_dataset

# %%
# load the data 
data = load_dataset("lukebarousse/data_jobs")

# %%
# convert data to pandas dataframe
df = data['train'].to_pandas()

# %%
# data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
# copy the df to df_DA_US with job_title = Data Analyst and job_country = United States
df_DA_US = df[(df['job_title'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# %%
# create new col named job_posted_month_no to extract month from job_posted_date
df_DA_US['job_posted_month_no'] = df_DA_US['job_posted_date'].dt.month

# %%
# explode job_skills and assign it to new var called df_DA_US_explode
df_DA_US_explode = df_DA_US.explode('job_skills')

# %%
# make a pivot table
df_DA_US_pivot = df_DA_US_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size', fill_value=0)

# %%
df_DA_US_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  ansible  apl  arch  \
# job_posted_month_no
# 1                         12         0       53        0        1    0     0
# 2                         13         0       34        1        2    0     0
# 3                         11         0       41        1        3    0     0
# 4                          5         0       57        1        0    0     0
# 5                          6         1       35        0        3    0     0
# 6                         10         3       33        1        1    0     2
# 7                         13         0       33        0        1    0     0
# 8                          9         2       29        0        0    0     0
# 9                          7         0       19        1        0    1     0
# 10                         7         3       16        1        0    0     1
# 11                         6         0       24        0        0    0     0
# ...

# %%
# create a new row named total that sum up each col
df_DA_US_pivot.loc['Total'] = df_DA_US_pivot.sum()

# %%
df_DA_US_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  ansible  apl  arch  \
# job_posted_month_no
# 1                         12         0       53        0        1    0     0
# 2                         13         0       34        1        2    0     0
# 3                         11         0       41        1        3    0     0
# 4                          5         0       57        1        0    0     0
# 5                          6         1       35        0        3    0     0
# 6                         10         3       33        1        1    0     2
# 7                         13         0       33        0        1    0     0
# 8                          9         2       29        0        0    0     0
# 9                          7         0       19        1        0    1     0
# 10                         7         3       16        1        0    0     1
# 11                         6         0       24        0        0    0     0
# ...

# %%
# sort the df_DA_US_pivot base on total DESC using loc
df_DA_US_pivot = df_DA_US_pivot[df_DA_US_pivot.loc['Total'].sort_values(ascending=False).index]

# %%
df_DA_US_pivot
# Out:
# job_skills            sql  excel  tableau  python  power bi   sas     r  word  \
# job_posted_month_no
# 1                    1138    781      646     529       326   394   338   169
# 2                     782    544      408     378       302   270   233   128
# 3                     802    580      463     400       277   300   241   142
# 4                     845    577      462     421       292   258   238   143
# 5                     706    490      367     336       251   206   219    92
# 6                     742    491      395     396       272   202   252   126
# 7                     560    431      296     292       190   182   188   101
# 8                     784    641      480     460       292   272   321   112
# 9                     485    336      277     253       183   150   157    65
# 10                    556    343      308     270       207   150   154    76
# 11                    472    291      246     234       168   146   120    61
# ...

# %%
# let drop the total raw
df_DA_US_pivot = df_DA_US_pivot.drop('Total')

# %%
df_DA_US_pivot
# Out:
# job_skills            sql  excel  tableau  python  power bi  sas    r  word  \
# job_posted_month_no
# 1                    1138    781      646     529       326  394  338   169
# 2                     782    544      408     378       302  270  233   128
# 3                     802    580      463     400       277  300  241   142
# 4                     845    577      462     421       292  258  238   143
# 5                     706    490      367     336       251  206  219    92
# 6                     742    491      395     396       272  202  252   126
# 7                     560    431      296     292       190  182  188   101
# 8                     784    641      480     460       292  272  321   112
# 9                     485    336      277     253       183  150  157    65
# 10                    556    343      308     270       207  150  154    76
# 11                    472    291      246     234       168  146  120    61
# ...

# %%
# plot line chart
df_DA_US_pivot.plot(kind='line', figsize=(12, 6), marker='o')
# Out:
# <Axes: xlabel='job_posted_month_no'>

# %%
# lets size the job_posted_month_no of df_DA_US 
DA_totals = df_DA_US.groupby('job_posted_month_no').size()

# %%
# lets make the df_DA_US.pivot devided by DA_totals
df_DA_US_percent = df_DA_US_pivot.div(DA_totals/100, axis=0)

# %%
df_DA_US_percent
# Out:
# job_skills                 sql      excel    tableau     python   power bi  \
# job_posted_month_no
# 1                    62.665198  43.006608  35.572687  29.129956  17.951542
# 2                    60.903427  42.367601  31.775701  29.439252  23.520249
# 3                    58.883994  42.584435  33.994126  29.368576  20.337739
# 4                    61.723886  42.147553  33.747261  30.752374  21.329438
# 5                    61.072664  42.387543  31.747405  29.065744  21.712803
# 6                    61.474731  40.679370  32.725766  32.808616  22.535211
# 7                    58.638743  45.130890  30.994764  30.575916  19.895288
# 8                    55.445545  45.332390  33.946252  32.531825  20.650636
# 9                    56.658879  39.252336  32.359813  29.556075  21.378505
# 10                   55.489022  34.231537  30.738523  26.946108  20.658683
# 11                   55.660377  34.316038  29.009434  27.594340  19.811321
# ...

# %%
# change month number to month name
df_DA_US_percent = df_DA_US_percent.reset_index()
df_DA_US_percent['job_posted_month'] = df_DA_US_percent['job_posted_month_no'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
df_DA_US_percent = df_DA_US_percent.drop(columns='job_posted_month_no')

# %%
df_DA_US_percent
# Out:
# job_skills        sql      excel    tableau     python   power bi        sas  \
# 0           62.665198  43.006608  35.572687  29.129956  17.951542  21.696035
# 1           60.903427  42.367601  31.775701  29.439252  23.520249  21.028037
# 2           58.883994  42.584435  33.994126  29.368576  20.337739  22.026432
# 3           61.723886  42.147553  33.747261  30.752374  21.329438  18.845873
# 4           61.072664  42.387543  31.747405  29.065744  21.712803  17.820069
# 5           61.474731  40.679370  32.725766  32.808616  22.535211  16.735708
# 6           58.638743  45.130890  30.994764  30.575916  19.895288  19.057592
# 7           55.445545  45.332390  33.946252  32.531825  20.650636  19.236209
# 8           56.658879  39.252336  32.359813  29.556075  21.378505  17.523364
# 9           55.489022  34.231537  30.738523  26.946108  20.658683  14.970060
# 10          55.660377  34.316038  29.009434  27.594340  19.811321  17.216981
# ...

# %%
# change job_posted_month to be first col
df_DA_US_percent = df_DA_US_percent[['job_posted_month'] + [col for col in df_DA_US_percent.columns if col != 'job_posted_month']]

# %%
df_DA_US_percent
# Out:
# job_skills job_posted_month        sql      excel    tableau     python  \
# 0                       Jan  62.665198  43.006608  35.572687  29.129956
# 1                       Feb  60.903427  42.367601  31.775701  29.439252
# 2                       Mar  58.883994  42.584435  33.994126  29.368576
# 3                       Apr  61.723886  42.147553  33.747261  30.752374
# 4                       May  61.072664  42.387543  31.747405  29.065744
# 5                       Jun  61.474731  40.679370  32.725766  32.808616
# 6                       Jul  58.638743  45.130890  30.994764  30.575916
# 7                       Aug  55.445545  45.332390  33.946252  32.531825
# 8                       Sep  56.658879  39.252336  32.359813  29.556075
# 9                       Oct  55.489022  34.231537  30.738523  26.946108
# 10                      Nov  55.660377  34.316038  29.009434  27.594340
# 11                      Dec  52.998776  39.657283  29.865361  32.925337
#
# ...

# %%
df_DA_US_percent
# Out:
# job_skills job_posted_month        sql      excel    tableau     python  \
# 0                       Jan  62.665198  43.006608  35.572687  29.129956
# 1                       Feb  60.903427  42.367601  31.775701  29.439252
# 2                       Mar  58.883994  42.584435  33.994126  29.368576
# 3                       Apr  61.723886  42.147553  33.747261  30.752374
# 4                       May  61.072664  42.387543  31.747405  29.065744
# 5                       Jun  61.474731  40.679370  32.725766  32.808616
# 6                       Jul  58.638743  45.130890  30.994764  30.575916
# 7                       Aug  55.445545  45.332390  33.946252  32.531825
# 8                       Sep  56.658879  39.252336  32.359813  29.556075
# 9                       Oct  55.489022  34.231537  30.738523  26.946108
# 10                      Nov  55.660377  34.316038  29.009434  27.594340
# 11                      Dec  52.998776  39.657283  29.865361  32.925337
#
# ...

# %%
# get the first 5 using iloc
df_plot = df_DA_US_percent.iloc[:, :5]

# %%
df_plot
# Out:
# job_skills job_posted_month        sql      excel    tableau     python
# 0                       Jan  62.665198  43.006608  35.572687  29.129956
# 1                       Feb  60.903427  42.367601  31.775701  29.439252
# 2                       Mar  58.883994  42.584435  33.994126  29.368576
# 3                       Apr  61.723886  42.147553  33.747261  30.752374
# 4                       May  61.072664  42.387543  31.747405  29.065744
# 5                       Jun  61.474731  40.679370  32.725766  32.808616
# 6                       Jul  58.638743  45.130890  30.994764  30.575916
# 7                       Aug  55.445545  45.332390  33.946252  32.531825
# 8                       Sep  56.658879  39.252336  32.359813  29.556075
# 9                       Oct  55.489022  34.231537  30.738523  26.946108
# 10                      Nov  55.660377  34.316038  29.009434  27.594340
# 11                      Dec  52.998776  39.657283  29.865361  32.925337

# %%
# plot df_plot witn seabon
sns.lineplot(data=df_plot, dashes=False, palette='tab10')
sns.set_theme(style="whitegrid", context="talk", palette="deep")

plt.title('Data Analyst Skills Trends in the US')
plt.xlabel('Month')
plt.ylabel('Percentage (%)')
# Out:
# Text(0, 0.5, 'Percentage (%)')
